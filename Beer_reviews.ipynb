# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('beer_reviews.csv')
df
# Out:
#                                               Name  \
# 0           pFriem Family Brewers Czech Dark Lager
# 1                       Yazoo Brewing Brett Saison
# 2                Perennial Artisan Ales Maman 2018
# 3    Other Half Bourbon Barrel Aged Pastrytown VIP
# 4                  New Anthem Brewing Songs Unsung
# ..                                             ...
# 993              Moksa Brewing Pineapple SUPERFUZZ
# 994                         Maplewood Son of Juice
# 995                      Finback Brewery Four Year
# 996                      Corridor Brewery Squeezit
# 997              Bootstrap Brewing Insane Rush IPA
#
#                                           Style  \
# 0                 Style: Czech-Style Dark Lager
# 1         Style: Mixed Culture Saison/Farmhouse
# 2             Style: Barrel-Aged Imperial Stout
# 3    Style: Barrel-Aged Vanilla & Coconut Stout
# 4                        Style: Hazy Single IPA
# ..                                          ...
# ...

# %%
print(df.shape)
# Out:
# (998, 12)

# %%
df.tail(75)
# Out:
# Empty DataFrame
# Columns: [Name, Style, Brewer_comments, Panel_comments, Editor_comments, ABV, IBU, Score, Aroma, Appearance, Flavor, Mouthfeel]
# Index: []
